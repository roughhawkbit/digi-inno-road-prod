# %% [markdown]
# <a href="https://colab.research.google.com/github/roughhawkbit/digi-inno-road-prod/blob/main/analysis/PackageVersions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datasets
datasets.__version__
# Out:
# '4.0.0'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.10.0'

# %%
import numpy
numpy.__version__
# Out:
# '2.0.2'

# %%
import pandas
pandas.__version__
# Out:
# '2.2.2'

# %%
import re
re.__version__
# Out:
# '2.2.1'

# %%
import sklearn
sklearn.__version__
# Out:
# '1.6.1'

# %%
import statsmodels
statsmodels.__version__
# Out:
# '0.14.6'

# %%
import transformers
transformers.__version__
# Out:
# '5.0.0'

# %%
# import
# .__version__
