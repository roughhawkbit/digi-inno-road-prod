# %% [markdown]
# <a href="https://colab.research.google.com/github/roughhawkbit/digi-inno-road-prod/blob/main/x_accessing_sourcecode_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook explores optins for accessing the sourcecode wihtin the [innoprod](https://github.com/roughhawkbit/digi-inno-road-prod/tree/main/innoprod) folder of [the repository](https://github.com/roughhawkbit/digi-inno-road-prod).

# %%
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if not IN_COLAB:
    print('Run this notebook in Google Colab!')

# %% [markdown]
# When running this next line for the first time, you will be asked to confirm that you are willing to allow the notebook to connect to your Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.path.isdir('/content/drive/MyDrive/digi-inno-road-prod')
# Out:
# True

# %% [markdown]
# If the repository is already cloned into our Google Drive then we ensure that it is up-to-date by pulling the latest changes. If not, then we clone it from GitHub.

# %%
if os.path.isdir('/content/drive/MyDrive/digi-inno-road-prod'):
  cwd = os.getcwd()
  os.chdir('/content/drive/MyDrive/digi-inno-road-prod')
  # !git pull
  os.chdir(cwd)
else:
  # !git clone https://github.com/roughhawkbit/digi-inno-road-prod.git
  print('Repository cloned into your Google Drive. It is strongly recommended that you copy the credentials.json, sheet.json, and token.json files into the secrets folder before proceeding.')
# Out:
# Already up to date.
