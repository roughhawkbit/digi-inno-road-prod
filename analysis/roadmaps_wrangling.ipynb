# %%
import json
import os
import pandas as pd
import sys

module_path = os.path.abspath(os.path.join('../src'))
if not module_path in sys.path:
    sys.path.insert(0, module_path)

from innoprod.sheet_tools import get_sheet_dfs

# %%
data = get_sheet_dfs()
roadmaps_df = data['Roadmaps']

# %%
for col in roadmaps_df.columns:
    print(col)
# Out:
# Client ID
# Number of GAFs
# Referral Source
# Primary_contact_id
# LEP
# Local Authority
# Nature of Business/core activity
# Turnover
# Enquiry Date
# Org Size by Number of FTE (calc)
# Number of FTE Employees (calc)
# Number of FT employees
# Number of PT employees
# Registration Form Complete
# Edge Digital Diagnostic Complete
# GROWTHmapper Diagnostic Date
# Roadmap Complete
# Summary review of Edge Digital diagnostic report & current state and key improvement areas
# Current Digital Readiness Score (refer to PAS:1040)
# What are the internal barriers to growth? How do you intend to finance future growth? Are there sufficient leadership and management skills in the business to achieve your growth? What opportunities do you have to expand into new markets?
# Main historical barrier
# Details of any existing Digital Strategy
# Do you have a Digital Champion in place?
# Level of current Strategic Digital Skills/knowledge in the business
# Level of current Technical Digital Skills/knowledge in the business
# Whether the business is already investing/adopting/utilising Industry 4.0 Technologies, with examples
# Summary of the identified problems, including Gap Analysis
# Key potential industry 4.0 solutions to address the identified problems/gaps
# Recommended Action Plan to utilise Industry 4.0 Technology
# Overview of qualitative benefits of recommended Action Plan (positive/negative)
# Skills and other requirements that will be needed to successfully implement the recommended Action Plan
# Application area of technology in the Action Plan
# Sub-application area of technology in the Action Plan
# Anticipated resulting Digital Readiness Score (refer to PAS:1040)
# Anticipated Made Smarter Support Package(s) to be accessed
# Other business support referrals
# Requirements/Plans: Short Term
# Requirements/Plans: Medium Term
# Requirements/Plans: Long Term
# Employee Increase (FTE calc)
# SDR Complete Date
# How did you find the process of accessing the programme?
# How valuable did you find the involvement of your contact within the programme during the course of the support?
# How valuable did you find the GROWTHmapper and its report in identifying the key areas of supporting your business?
# How valuable did you find the support you received from the Expert Coach during the course of the programme?
# To what extent were you satisfied with the Programme overall?
# Would you recommend the Programme to others?
# What has been your overall opinion of the support you have received in this programme? (Add comments)
# Willing to be approached for case study?
# Industry 4.0 Technology Adopted
# Has the intervention supported higher skilled, higher paid jobs? If so, why?
# Employees at Project Completion (FTE)
# At risk jobs still in existence post support - FTE (Jobs Safeguarded)
# Tonnes CO2 Reduction
# Innovation/R&D Spend (post) for past year (including new product design)
# Tonnes Waste Reduction to Landfill
# Has resource consumption (electricity, gas, waste, and water) or Greenhouse Gas emissions reduced since you started working with the Programme?
# Increased Turnover £
# Increased Pre-Tax Profits
# Increased TO/Employee
# Increased GVA

# %% [markdown]
# ## Simple strings - unique identifiers
# * Client ID
# * Primary contact ID
# *

# %%
roadmaps_df['Referral Source']
# Out:
# 0          Internally sourced
# 1          Internally sourced
# 2            Another business
# 3            Networking event
# 4      Social Media: LinkedIn
#                 ...
# 215
# 216
# 217    Other business support
# 218          Networking event
# 219            Email Campaign
# Name: Referral Source, Length: 220, dtype: str

# %%
roadmaps_df['Client ID']
# Out:
# 0      f3fff05d-1a28-e8f3-c5f6-670d1d0797e3
# 1      458079bc-a5ab-2055-d514-6733331e9c5f
# 2      0369B4F9-9E83-E83D-9E6B-BF82E264A2BA
# 3      e9b5b5a2-1ba0-1d3a-a374-67ed061c1e40
# 4      052CB881-3557-DCFA-E472-0E55A5D04590
#                        ...
# 215    0EC71AFB-5867-DE5F-5061-32AEAE4B24BF
# 216    2346FC83-5B42-B90D-3BBB-16BFD156902E
# 217    2AA6320B-75FF-BABC-1E79-EB96B0AE650E
# 218    38392b05-1eeb-493a-95de-66fa836a6470
# 219    40E8F83B-29FA-B32B-F9FD-4B41B053273A
# Name: Client ID, Length: 220, dtype: str

# %%
roadmaps_df['Primary_contact_id']
# Out:
# 0      e8ad1505-5458-410c-d206-670d1d60d94f
# 1      2F6A3773-355E-213C-A71A-B65FAB3569F3
# 2      419E42F8-6EDC-53E3-24EA-E8ECCFFC5E22
# 3      e36f6501-13e8-8578-6577-67ed06a74f3e
# 4      6B31AC2C-B7FF-18ED-6AB0-F985137D6605
#                        ...
# 215    C55AC018-EC46-F4D3-7735-C7115A80E197
# 216    EC02DEF5-2E58-3086-F01D-C230CEE4F51A
# 217    8FA821E5-38F5-0E82-DA9B-EFF12BA0697D
# 218    341f4a40-1818-b246-3f1d-66fa83666332
# 219    CAB53AD0-89BB-890B-DCA0-190E79758EBC
# Name: Primary_contact_id, Length: 220, dtype: str

# %% [markdown]
# # Complex strings
# * Summary review of Edge Digital diagnostic report & current state and key improvement areas
# * What are the internal barriers to growth? How do you intend to finance future growth? Are there sufficient leadership and management skills in the business to achieve your growth? What opportunities do you have to expand into new markets?
# * Details of any existing Digital Strategy
# * Level of current Strategic Digital Skills/knowledge in the business
# * Level of current Technical Digital Skills/knowledge in the business

# %%
roadmaps_df['Summary review of Edge Digital diagnostic report & current state and key improvement areas']
# Out:
# 0      [REDACTED] business has completed an edge digi...
# 1      [REDACTED] Score: 7\n STATUS: Based on your re...
# 2      The EDD has identified that the Company has in...
# 3      Summary review of [REDACTED] diagnostic report...
# 4      The business has rated itself at level 4 in te...
#                              ...
# 215    [REDACTED] Score: 6\n STATUS: Based on the res...
# 216    Whites have started to invest significantly in...
# 217    Company has invested some data and digital tec...
# 218    The EDD has a given digital readiness score of...
# 219    [REDACTED] Score: STATUS: Based on the respons...
# Name: Summary review of Edge Digital diagnostic report & current state and key improvement areas, Length: 220, dtype: str

# %%
roadmaps_df['Details of any existing Digital Strategy']
# Out:
# 0      The company has no formal digital or innovatio...
# 1      Nothing documented, but they do have some visi...
# 2      The company has an overall growth strategy of ...
# 3      Yes. [REDACTED] and [REDACTED] team have creat...
# 4      No formal digital strategy is in place, the bu...
#                              ...
# 215    There is no formal digital and innovation stra...
# 216    Aiming to gain more understanding of current d...
# 217     No formal digital strategy is currently in place
# 218    The company does not, currently, have a [REDAC...
# 219    Nothing documented, but they do have some visi...
# Name: Details of any existing Digital Strategy, Length: 220, dtype: str

# %%
col = 'Level of current Strategic Digital Skills/knowledge in the business'
roadmaps_df[col].unique()
# Out:
# <StringArray>
# [                                                                                                                                                                                                                                                                                                                                                                                                                                          '[REDACTED] is reasonably experienced in terms of business management and has good strategic management experience, this extends to\n understanding the benefits of enhancing the use of digital solutions to both manufacturing, administrative and\n management function. She hasrecognised the limitations that physical resource creates in increasing\n productivity and see technology and automation as the most likely route to increasing both productivity and\n profitability, and is committed to development of ongoing technology strategy to inform\n both new product and process development.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'The current level of Strategic Digital Skills/Knowledge is seen as room for improvement, given the limited utilisation and investment in digital technology that they have already made.',
#                                                                                                                                                                                                                                                      'here are good levels of business strategic skills in the business and the management team has a good level of understanding around the fundamentals of business management. They are aware of the opportunities for growth that increased digitisation can bring having built the business to its current position. Although no formal digital strategy exists, the management team is aware of the areas in which digitisation can further improve productivity and profitability and it is likely that MS funding will support here once specific costings and suppliers have been identified. These strategic skills could be further enhanced by accessing the MS Leadership and Management course, specifically to help with the challenges of managing change through increased digitisation.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            'Limited/mixed given the limited utilisation and investment in digital technology that they have already made.',
#                                                                                                                                                                                                                                                                                 'The business has an enthusiatic and technically experienced leadership team but potentially with limited strategic management experience, they understand the benefits of enhancing the use of digital solutions to both manufacturing, administrative and management functions.\n The current leadership team have overseen the development of the business from concept to reality and actively recognise that opportunities for increased digitisation/automation that will improve the productivity and profitability of the business.\n Implementation of new technology is seen as a key driver to onward business growth and the company are committed to developing internal skills where necessary to support the successful transference of these new methods.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'The current level of Strategic Digital Skills/Knowledge is limited/mixed given the limited utilisation and investment in digital technology that they have already made. It is weaker within the customer facing and operational side and stronger in the areas of quality and engineering.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'They have a Medium to High level of Strategic Digital Skills and Knowledge within the business. They recognise the power of Industry 4.0 technologies (in particular Additive Manufacturing) but they know they are not utilising Big Data & Analytics.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'The current level of Strategic Digital Skills/Knowledge is limited/mixed given the limited utilisation and investment in digital technology that they have already made.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                'The business has a strong leadership team with good strategic management experience, this extends to understanding the benefits of enhancing the use of digital solutions to both manufacturing, administrative and management function. They have recognised the limitations that physical resource creates in increasing productivity and see technology and automation as the most likely route to increasing both productivity and profitability, the management team are committed to development of ongoing technology strategy to inform both new product and process development.',
#                                                                                                                                                                                                                                                                                                                                                                   'As with many business one of the main barriers to investment in Digital Technology has been accessing the finance to support investment, specifically in respect to capital equipment which comes at substantive cost. AET have incorporated automation in their manufacturing equipment to support operations where possible They have used external resource for the development of IT/CRM systems but with this reliance the internal skills have not been developed to undertake this work in house. The management are progressive and forward thinking and see technology as a means of enhancing productivity but need to balance investment with demonstrable business returns',
#  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     '[REDACTED] possesses a high level of strategic digital skills / knowledge with a great deal of awareness of the need to invest in digital to maintain competitive advantage. Levels of knowledge in the wider business appears to be relatively low.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'The current level of Strategic Digital Skills/Knowledge is quite good given the limited utilisation and investment\n in digital technology that they have already made.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'A young workforce with a fairly mixed skills set in terms of the level of digital skills and knowledge.',
#                                                                                                                                                                                                                                                                                                                'The business has an enthusiatic and experienced leadership team with good strategic management experience, they understand the benefits of enhancing the use of digital solutions to both manufacturing, administrative and management functions.\n The current leadership team have overseen the development of the business from concept to reality and actively recognise that opportunities for increased digitisation/automation that will improve the productivity and profitability of the business.\n Implementation of new technology is seen as a key driver to onward business growth and the company are committed to developing internal skills where necessary to support the successful transference of these new methods.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'Management have a high level of strategic skills and knowledge, they fully recognise the potential of digital automation and digital connectivity technologies to improve productivity within the business.\n Their vision is to further exploit this potential to enable both growth and productivity.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    '[REDACTED] has a huge amount of experience in digital and has a very clear understanding of the strategic importance of Industry 4.0.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'There is medium level of strategic digital skills / knowledge in the business. With Danny, a qualified accountant and [REDACTED], an experienced\n manufacturer, their skills and knowledge complement each other, but neither have a background in digital. However, they both understand\n the strategic importance of digital to the company's future and, as outlined above, are working to improve their knowledge.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'A young workforce with a good level of digital skills and knowledge. Good level of knowledge on Smartsheet throughout the business.',
#  'The company benefits from a reasonably experienced leadership team, however there is scope to enhance these skills across the wider scope of business management particularly supporting this with increased levels of in house digital technology awareness where it underpins the product offer.\n The lack of a formal digital strategy demonstrates that there is scope for development of necessary levels of strategic skills associated within the implementation of digitisation internally to support the businesses productivty growth, especially given the acknowledged challenges of identifying and recruiting suitable levels of new talent.\n In addition to specialist support to develop a digital and innovation strategy, the company should give consideration to accessing the Leadership and Management training offer available within Made Smarter in order to build greater levels of internal capacity to assess, manage and implement digital transformation as a means of underpinning future sustainable business growth.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'The level of strategic digital skills is low, however, the business owners are addressing this by researching digital solutions, attending workshops, and networking with other manufacturing businesses to share experience and best practice.']
# Length: 148, dtype: str

# %%
col = 'Level of current Technical Digital Skills/knowledge in the business'
roadmaps_df[col].unique()
# Out:
# <StringArray>
# [                              'The business has limited technical digital skills in relation to the use of digital systems and technology and it is\n recognised that they lack key competence to maximise the development of their internal data collection, analysis and management functionality. There are also gaps in addressing other elements of digitisation which\n are critical to sales and marketing activity such as remote document control and access and specifically\n enhancing levels of cybersecurity and how this can be aligned to existing data systems. Batch management\n and control, tracking, improving OEE are all areas where the company have analogue systems. They use Sage\n for managing the financial aspects of the business, but their processes are still heavily reliant on substantial\n manual data entry, extrapolation, analysis etc',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'The current level of technical Digital Skills/Knowledge is pretty good, with investment made into new apprentices that have developed good technical knowledge and skills.',
#                                                                                                                                                                                                                                                                                                                                                                'There are good levels of technical digital skill in the business, however these are currently fully engaged in the delivery of day to day operations. The company has developed systems and processes for digitising design specifications in order to upload these to the manufacturing systems and has recently invested in an MRP system (Thastern) and the willingness to adapt to new ways of working using technology is present - it is just constrained by time demands and lack of competence at present.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'Limited/mixed given the limited utilisation and investment in digital technology that they have already made.',
#                                                                                                                                                                                      'The levels of technical skills in the business are largely limited to current operating methods and systems but aligned to a novel manufacturing process that has limited competition. The company recognise that in order to successfully implement new digital solutions, they will need to identify key skills gaps and implement relevant training and development in order to refine working practices and maximise the return on investments planned. Introductions to local skills funding opportunities has been made (skillsbank/Advancing Digital) and the business also has an established relationship with both local universities and could explore potential for internships.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'The current level of technical Digital Skills/Knowledge is limited mixed given the limited utilisation and investment in digital technology that\n they have already made.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'The level of Technical Digital skills and knowledge in the business is High, given their utilisation of 3D printing, they have recently taken on more CAD resource, which will be done remotely.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'The current level of technical Digital Skills/Knowledge is limited mixed given the limited utilisation and investment in digital technology that they have already made.',
#                                            'The business has limited technical digital skills in relation to the use of digital systems and technology and it is recognised that they lack key competence to maximise the development of their internal data collection, analysis and management functionality. There are also gaps in addressing other elements of digitisation which are critical to sales and marketing activity such as remote document control and access and specifically enhancing levels of cybersecurity and how this can be aligned to existing data systems. Batch management and control, tracking, improving OEE are all areas where the company have analogue systems. They use Sage for managing the financial aspects of the business, but their processes are still heavily reliant on substantial manual data entry, extropolation, analysis etc',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'The company has no formal digital or innovation strategy, this is embedded within their wider business strategy and linked predominantly to the development of new product rather than implementation of digital technology as a means of supporting this process.',
#  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'The current level of technical Digital Skills/Knowledge is limited mixed given the limited utilisation and investment\n in digital technology that they have already made',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'The current level of Technical Digital Skills/Knowledge is Medium to High taking into account the specific technical skills relating to individual job roles within the workforce.',
#                                                                                                                                                                                                                                                                                                 'The levels of technical skills in the business are largely limited to current operating methods and systems. The company recognise that in order to successful implement new digital solutions, they will need to identify key skills gaps and implement relevant training and development in order to refine working practices and maximise the return on investments planned. Introductions to local skills funding opportunities has been made (skillsbank/Advancing Digital) and the business also has an established relationship with enterprising Barnsley and Mike Brook.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'Technical digital skills are somewhat limited in comparison, but only due to the outdated ERP, this will be addressed during the implementation of the new ERP solution.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'Matt has significant technical digital skills / knowledge, but acknowledges that, whilst RFID is not new, it is a new technology for him, and he is building his knowledge as he goes along. He also has access to a large group of experienced engineers that he can call upon.',
#                                                                                                                                                                                                                   'The workforce, particularly at a manufacturing level, have the skills which enable them to perform their day-to-day tasks, however, they are\n not exposed to a great deal of digital technology in their daily work. There has been some resistance to change, and this has resulted in a lack\n of progression with implementing Industry 4.0 technology on the shop floor. Danny concedes that there has been a lack of communication\n from the leadership, leading to the resistance to change however, he feels that by better communicating the benefits of new technology,\n employees will embrace the adoption of new technology rather than fear it.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               'A young workforce with a good level of digital skills and knowledge. Good level of knowledge on Smartsheet throughout the business.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'Limited in-house technical skills â€“ tech skills generally subbed in as required',
#  'One of main challenges for company's such as [REDACTED] is likely to be finding appropriately skilled staff, specifically with current employees who may be growing older and perhaps unwilling/unable to see the potential needs for change or increased digitisation. Younger employees are needed to be recruited into these positions, and ultimately retained, rather than them just being trained and then leaving â€“ the company need to upskill, and provide a stable workforce to support growth this needs to extend beyond wages as means of creating the deciding factor for employees when considering their options.\n The business has good level of technical skills in the application of the current digital technologies applied in the company, however a skills audit would be beneficial to ensure any future investments can generate immediate returns.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'The level of Technical Digital Skills/ knowledge is low and, again, the business owners are addressing this by engaging in the activities detailed above.']
# Length: 164, dtype: str

# %%
col = 'Whether the business is already investing/adopting/utilising Industry 4.0 Technologies, with examples'
roadmaps_df[col].unique()
# Out:
# <StringArray>
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     'The company use some limited IDT's including administrative/management systems and some internal data collection\n and analysis systems, They have internal data management systems although they have limitations in the use\n of this. They have started to explore the potential to include wider process automation in the manufacturing\n process - particularly to support increased digitisation of the largely analogue systems being applied to\n production scheduling, operational process planning etc. and stock management',
#                                                                                                                                                                                                                                                                                                                                                                                                                                  'Specifically relating to Industry 4.0 technologies. The business is looking to become fully automated, more\n streamlined and paperless however this is a process that will take sometime. No specific investment in industry 4.0\n technologies has been made to date but the business is keen to understand and communicate it's digital strategy and how it will drive innovation This needs to include the focus that has already started on the capturing of data via paperwork and spreadsheets. The ability to capture true data from the machines and resources that they use is key.',
#  'The business has a range of machinery which is all functional for the current operating purposes however many of the processes are still reliant on substantial manual engagement. The operational aspects of the business are well managed, and there are ongoing improvements and potential future projects looking at technology implementation to support ongoing progress etc. The initial improvements have been identified in the design and print management systems particularly implementing the use of MRP to facilitate more accurate and efficient production scheduling which is a critical element on their short run and bespoke design offerings.\n The company has recently implemented a package of consultancy support to increase levels of digitisation in the administrative functions which whilst not reaching the levels of a full scale erp system has enabled greater alignment with the integration of their Accounts Package and CRM for greater efficiency in production and stock management.',
#                                                                                                                                       'The Business will be implementing its first Microsoft ERP Solution at the end of Q1 FY25 - this will be first step into the world of automation and digitisation for the Business. However, the opportunities are vast and after attending a Make UK Seminar in May, Amanda is determined to put a Committee in place, who would be focused on a DIGITAL ROADMAP for the Business; exploring each and every corner of the Business, to determine where technology can play a part. The opportunities are wide and benefits significant. From Robotics, installing measuring devices/systems, to installing automated feed and inspection systems, to simple initiatives like logical movement of goods around the Mill, the Company is ready to explore. They acknowledge that they need help - developing their Digital Roadmap; understanding what good practices they can learn from.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               '',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'The website, product database, ERP and warehouse management system are all built in-house and thus their team of software developers are a core part of the company's ability to make changes. Technological investments have also been made in barcode scanning.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                'They have already implemented an ERP.\n And have heavily invested in Additive manufacturing (3D printers/printing) with support from Sparkfund.',
#                                                                                                                                                                                                                                                                                                                                                                                                       'Not specifically relating to Industry 4.0 technologies. The business is looking to become fully automated, more streamlined and paperless however this is a process that will take sometime. Many of the businesses processes have been digitised, such as timesheets and they do have an ERP system of sorts, (Velocity Management System) in place for many of the businesses processes. There has been no direct investment in Industry 4.0 technologies. No design software, such as CAD is used by the business however the business uses technology to monitor the temperature and humidity of meats such as beef.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'The company use some IDT's including administrative/management systems and some internal data collection and analysis systems, They have internal data management systems although they have limitations in the use of this. They have started to explore the potential to include wider process automation in the manufacturing process - particularly to support increased digitisation of the largely analogue systems being applied to production scheduling, operational process planning etc. and stock management',
#                                                                                                                                                                                                                                                        'The company use a wide range of IDT's including CAD/CAM, CNC and some internal data collection and analysis systems, They have internal data management systems incl CRM and full suite MRP and have developed their application of this to now provide full client journey management using the system. They have started to explore the potential to include automated testing systems in the manufacturing process, although this is still in the early adoption phase they see this as a likely integral technology moving forwards. They have also implemented GPS tracking of product/WIP in certain areas of their factory and see expanding this out across the entire site as well as increasing use of robots/cobots as crucial next steps in their evolution',
#  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   'Trust Electrical Heating are exploring the idea of using Artificial Intelligence for the development of their scheduling and reports. They currently have no stock system and the planning for stock is inadequate and they need to have a process that is efficient so they can control their cost of sale.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      'Company uses a range of IDT's from cloud based data, digital design through their website and internally with CAD/CAM, laser cutting and CNC cutting etc.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  'The business is already utilsing IDT's:-\n They make extensive use of CAD software to enhance their design process, which enables CAD drawings with 3D capability which fully utilises their 3D scanning technology that maps the vehicles for branding.\n The business also has the connectivity capability to link its CAD software and equipment to the Vinyl "wrap" printers.\n Their ERP is outdated which needs replacing, as well as including additional functionality, for example CRM capabilities.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        'The business is at a very early stage, therefore investment in specific industry 4.0 technologies has been limited, however, the aim of the business is to develop Industry 4.0 technologies and Matt has built a bespoke IoT platform for the company.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   'W J Components has invested heavily in digital with mixed success:\n The company currently uses a Pegasus Opera 3 ERP system which efficiently manages all of the back-office processes, from sales order to\n invoice, however, this has not been successfully implemented in production.\n Drawings are created in SolidWorks which produces 3D rendered drawings for customers and is connected to a flat-bed CNC Router.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         'Matterport is a cutting-edge platform that creates immersive 3D virtual tours of physical spaces. Waites Mechanical Services are using this technology to design components to fit into specific spaces. 3D Modelling.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'The business currently uses 3D modelling and printing to manufacture its product. The product is wifi enabled to network speaker units. Therefore Internet of Things (IoT) provides solutions to the connectivity side of things. The speakers they build for participatory arts are manufactured in four stages. CAD, splicing, printing and construction. The design of the speaker is given to the CAD designer, who collaborates with the designer to ensure the print meets requirements of aesthetics and structural integrity.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          'The company currently utilises a limited range of I4.0 technologies, largely relating to the financial and accounting elements of the company, there is scope to widen this out to digitise inventory and stock control, quality control/inspection, product and raw material traceability as well as building more robust understanding of client relationships, order cycles etc to inform both production scheduling, resource management and supply chain cycles.',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            '"Investment industry 4.0 / digital is limited. The company currently owns an entry level 3D printer and uses a free, online CAD package.\n For powder coating, the company has invested in a smart powder coating gun, which has advanced digital control features enabling more uniform powder distribution for improved finish quality, reducing powder waste and energy usage. "',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'Their IT systems include the normal Windows server driven network with around 15 work stations, their software ranges from MRP, resource planning, accountancy, CAD and CAM software packages. They are constantly looking to upgrade and improve equipment. They have invested in new machinery.']
# Length: 178, dtype: str

# %% [markdown]
# ## Integer values
# * Number of GAFs
# * Number of FTE Employees (calc)
# * Number of FT employees - some missing values ('')
# * Number of PT employees - some missing values ('')

# %%
roadmaps_df['Number of GAFs'].unique()
# Out:
# <StringArray>
# ['1', '2', '4', '3', '5']
# Length: 5, dtype: str

# %%
roadmaps_df['Number of GAFs'] = roadmaps_df['Number of GAFs'].astype(int)

# %%
roadmaps_df['Number of FTE Employees (calc)'].unique()
# Out:
# <IntegerArray>
# [   0,   10,    3, <NA>,   98,   30,  165,   82,   14,    8,   21,  103,   11,
#    72,   45,   28,    5,   19,   20,  140,   33,    7,   51,   43,   50,   17,
#    49,   92,   16,    1,   15,  129,   23,   79,   13,   46,   12,   25,   77,
#    75,  108,  110,   24,   27,  115,   36,    6,    4,   65,  220,   62,    2,
#    95,    9,   18,   70,   47,  200,   80,   96,   35,   40,   22]
# Length: 63, dtype: Int64

# %%
df = roadmaps_df
colname = 'Number of FTE Employees (calc)'
mask = df[colname] == ''
df.loc[mask, colname] = None

# %%
roadmaps_df['Number of FTE Employees (calc)'] = roadmaps_df['Number of FTE Employees (calc)'].astype("Int64")

# %%
roadmaps_df['Number of FT employees'].unique()
# Out:
# <StringArray>
# [   '',   '3',  '30', '165',  '82',  '14',   '8',  '21', '103',  '11',  '72',
#   '10',   '5',  '19',  '20', '140',  '33',  '51',  '43',  '17',  '49',  '92',
#   '16',   '7',  '15', '129',  '23',  '79',  '46',  '12',  '77',  '75', '108',
#   '24',  '27', '115',  '36',   '6',   '4',  '65',   '1', '220',   '2',  '45',
#    '9',  '18',  '70',  '47',  '50',  '80',  '96',  '25',  '35',  '40',  '22']
# Length: 55, dtype: str

# %%
roadmaps_df['Number of PT employees'].unique()
# Out:
# <StringArray>
# ['', '2', '0']
# Length: 3, dtype: str

# %%
pd.to_numeric(roadmaps_df['Number of PT employees'], downcast='Int64').unique() #
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pd.to_numeric(roadmaps_df['Number of PT employees'], downcast='Int64').unique() #
#
# File ~\miniconda3\envs\innoprod\Lib\site-packages\pandas\core\tools\numeric.py:180, in to_numeric(arg, errors, downcast, dtype_backend)
#      57 """
#      58 Convert argument to a numeric type.
#      59
#    (...)    177 dtype: Float32
#     178 """
#     179 if downcast not in (None, "integer", "signed", "unsigned", "float"):
# --> 180     raise ValueError("invalid downcasting method provided")
#     182 if errors not in ("raise", "coerce"):
#     183     raise ValueError("invalid error value specified")
#
# ValueError: invalid downcasting method provided

# %%
mask = roadmaps_df['Number of PT employees'] == ''
roadmaps_df.loc[mask, 'Number of PT employees'] = '0'
roadmaps_df['Number of PT employees']

# %% [markdown]
# ## Categoricals
# * Referral Source
# * LEP
# * Local Authority
# * Org Size by Number of FTE (calc)
# * Main historical barrier

# %%
roadmaps_df['Referral Source'].unique()

# %%
roadmaps_df['LEP'].unique()

# %%
roadmaps_df['Local Authority'].unique()

# %%
roadmaps_df['Org Size by Number of FTE (calc)'].unique()

# %%
roadmaps_df['Main historical barrier'].unique()

# %% [markdown]
# ## Financial
# * Turnover - in pounds, sometimes needs the £ symbol stripping out.

# %%
roadmaps_df['Turnover']

# %%
roadmaps_df['Turnover'] = roadmaps_df['Turnover'].str.replace(pat={'£':'', ',':''})
mask = roadmaps_df['Turnover'] == '-'
roadmaps_df.loc[mask, 'Turnover'] = ''
roadmaps_df['Turnover'] = pd.to_numeric(roadmaps_df['Turnover'])

# %%
roadmaps_df['Turnover']

# %% [markdown]
# ## Dates
# * Enquiry Date - (mm/dd/yy)
# * Registration Form Complete - (mm/dd/yy)
# * Edge Digital Diagnostic Complete - values missing
# * GROWTHmapper Diagnostic Date - values missing
# * Roadmap Complete

# %%
roadmaps_df['Enquiry Date']

# %%
pd.to_datetime(roadmaps_df['Enquiry Date'], format="%m/%d/%Y")

# %%
pd.to_datetime(roadmaps_df['Registration Form Complete'], format="%m/%d/%Y")

# %%
roadmaps_df['Edge Digital Diagnostic Complete']

# %%
pd.to_datetime(roadmaps_df['Edge Digital Diagnostic Complete'], format="%m/%d/%Y")

# %%
roadmaps_df['GROWTHmapper Diagnostic Date']

# %%
roadmaps_df['Roadmap Complete']

# %% [markdown]
# ## Boolean with missing values
# * Do you have a Digital Champion in place?

# %%
col = 'Do you have a Digital Champion in place?'
roadmaps_df[col].unique()

# %% [markdown]
# ## Questionable
# * Nature of Business/core activity - considerable overlap between values, but too many unique values to be a categorical. Needs some tidying up?

# %%
roadmaps_df['Nature of Business/core activity'].count()

# %%
roadmaps_df['Nature of Business/core activity'].unique()

# %%
col = 'Level of current Strategic Digital Skills/knowledge in the business'
roadmaps_df[col].unique()

# %%
roadmaps_df[col].unique()
